# %%
import os
import requests
import base64

# API endpoint URL
url = 'http://8.12.5.48:11434/api/generate'

# Your email and password for authentication
email = 'akshayalnyn@gmail.com'
password = 'akshu2001'

# Read and encode the image in base64
with open(os.getcwd()+'\\dress_B0006HJ8FU.jpg', 'rb') as image_file:
    image_data = base64.b64encode(image_file.read()).decode('utf-8')

# Payload data with an image encoded in base64
payload = {
    "model": "llava:7b-v1.6-mistral-q5_K_M",
    "prompt": "Write an instagram caption for me for the dress in the image.",
    "stream": False,
    "images": [image_data]
}

# Send POST request with authentication headers
response = requests.post(url, json=payload, auth=(email, password))

# Check response status
if response.status_code == 200:
    # Print the response content
    print(response.json()['response'])
else:
    print(f"Error accessing the API: {response.status_code} - {response.text}")
# Out:
#  "Embracing the elegance of sophistication in my favorite little black dress. 💋🌹 #FashionistaVibes #CocktailChic #StyleGoals"

# %% [markdown]
# # Describe the dress

# %%
import os
import requests
import base64

# API endpoint URL
url = 'http://8.12.5.48:11434/api/generate'

# Your email and password for authentication
email = 'akshayalnyn@gmail.com'
password = 'akshu2001'

# Read and encode the image in base64
with open(os.getcwd()+'\\dress_B0006HJ8FU.jpg', 'rb') as image_file:
    image_data = base64.b64encode(image_file.read()).decode('utf-8')

# Payload data with an image encoded in base64
payload = {
    "model": "llava:7b-v1.6-mistral-q5_K_M",
    "prompt": "Describe the dress in the image in detail.",
    "stream": False,
    "images": [image_data]
}

# Send POST request with authentication headers
response = requests.post(url, json=payload, auth=(email, password))

# Check response status
if response.status_code == 200:
    # Print the response content
    print(response.json()['response'])
else:
    print(f"Error accessing the API: {response.status_code} - {response.text}")
# Out:
#  The dress in the image is a sleeveless, floor-length gown. It features a V-neckline and a deep scoop back. The fabric appears to be a solid color, likely black or dark brown, and it has a fitted waist that flares out slightly towards the hem. The overall style of the dress suggests it could be suitable for formal events or evening wear.

# %% [markdown]
# # Suggest improvements and accessories

# %%
import os
import requests
import base64

# API endpoint URL
url = 'http://8.12.5.48:11434/api/generate'

# Your email and password for authentication
email = 'akshayalnyn@gmail.com'
password = 'akshu2001'

# Read and encode the image in base64
with open(os.getcwd()+'\\dress_B0006HJ8FU.jpg', 'rb') as image_file:
    image_data = base64.b64encode(image_file.read()).decode('utf-8')

# Payload data with an image encoded in base64 and a prompt for outfit change
payload = {
    "model": "llava:7b-v1.6-mistral-q5_K_M",
    "prompt": '''How can I improve this dress? Suggest how the stitching can be modified and 
    what other color combinations can be used to make it more appealing. Also tell me how I can use 
    accesories to make it more elegant. Avoid using word like image or model. Use second person language
    to create rapport with user. Suggest like a human with a playful tone''',
    "stream": False,
    "images": [image_data]
}

# Send POST request with authentication headers
response = requests.post(url, json=payload, auth=(email, password))

# Check response status
if response.status_code == 200:
    # Print the response content
    print(response.json()['response'])
else:
    print(f"Error accessing the API: {response.status_code} - {response.text}")
# Out:
#  Hey there! To give your dress a little boost, you might consider the following ideas:
#
# 1. **Sewing Modifications**: You can try adding a belt or a sash to accentuate your waistline and add some shape to the silhouette. If you want to add a bit of flair, consider adding some ruffles or lace detailing to the sleeves or hem.
#
# 2. **Color Combos**: For a more appealing look, you could experiment with different color combinations. A classic black dress can be elevated with some subtle color accents like silver or gold for a touch of luxury, or a soft pink for a romantic vibe.
#
# 3. **Accessories**: Accessories are the key to making your dress more elegant! You could pair it with a statement necklace to add an air of sophistication. A pearl bracelet or earrings would be a subtle way to enhance the elegance without overwhelming the outfit. For shoes, you might consider strappy heels in a metallic finish like silver or gold for a glamorous touch.
#
# ...

# %% [markdown]
# # Occasion

# %% [raw]
# 1. Give input Picture and ask for occassion

# %%
import os
import requests
import base64

# API endpoint URL
url = 'http://8.12.5.48:11434/api/generate'

# Your email and password for authentication
email = 'akshayalnyn@gmail.com'
password = 'akshu2001'

# Read and encode the image in base64
with open(os.getcwd()+'\\dress_B0006HJ8FU.jpg', 'rb') as image_file:
    image_data = base64.b64encode(image_file.read()).decode('utf-8')

# Payload data with an image encoded in base64 and a prompt for outfit change
payload = {
    "model": "llava:7b-v1.6-mistral-q5_K_M",
    "prompt": '''Which occasion does this dress suit? . Avoid using word like image or model. Use second person language
    to create rapport with user. Suggest like a human with a playful tone''',
    "stream": False,
    "images": [image_data]
}

# Send POST request with authentication headers
response = requests.post(url, json=payload, auth=(email, password))

# Check response status
if response.status_code == 200:
    # Print the response content
    print(response.json()['response'])
else:
    print(f"Error accessing the API: {response.status_code} - {response.text}")

# %% [raw]
# given an occasion, generate image

# %%
import os
import base64
import requests
from PIL import Image
from io import BytesIO

# API endpoint URLs
llava_url = 'http://8.12.5.48:11434/api/generate'
runwayml_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
first_image_link = None  # Variable to store the link of the first image
modifications = []  # List to store user-specified modifications

# Prompt the user for an occasion
occasion = input("Enter the occasion for dressing up: ")

while True:
    # Prompt the user for a question or exit option
    user_input = input("Ask the model a question about the dress or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to select the type of suggestions they want
    print("Select the type of suggestions you want:")
    print("1. Outfit")
    print("2. Accessories")
    print("3. Shoes")
    print("4. Handbags")
    option = input("Enter the option number: ")

    # Add selected options to the LLAVA prompt
    selected_options = []
    if '1' in option:
        selected_options.append('outfit')
    if '2' in option:
        selected_options.append('accessories')
    if '3' in option:
        selected_options.append('shoes')
    if '4' in option:
        selected_options.append('handbags')

    # Add a string before the user's question for LLAVA prompt
    llava_prompt = f'''For the occasion "{occasion}", suggest outfits, accessories, shoes, and handbags.
    Give suggestions for: {", ".join(selected_options)} based on the following input: {user_input}'''

    if first_image_link is None:
        # Read and encode the first image in base64
        first_image_path = os.getcwd() + '\\dress_B0006HJ91S.jpg'
        with open(first_image_path, 'rb') as first_image_file:
            first_image_data = base64.b64encode(first_image_file.read()).decode('utf-8')
        first_image_link = first_image_data  # Store the link for the first image

    # Apply previous modifications to the LLAVA prompt
    modified_prompt = llava_prompt
    for mod in modifications:
        modified_prompt += f"\n{mod}"

    # Payload data for LLAVA model with image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": modified_prompt,
        "stream": False,
        "images": [first_image_link]  # Use the link of the first image as input
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Check if the user wants to change the dress and there is a suggestion from LLAVA
    if change_dress and llava_suggestion:
        # Prompt the user for modifications to add
        modification_input = input("Specify the modifications you want to add: ")

        # Add the modifications input to the list of modifications
        modifications.append(modification_input)

    # Check if there is a suggestion from LLAVA after adding modifications
    if llava_suggestion:
        # Payload data for Diffusion model
        diffusion_payload = {
            "inputs": llava_suggestion
        }
        
        # Send POST request to Diffusion model
        diffusion_response = requests.post(runwayml_url, json=diffusion_payload, headers=headers)

        if diffusion_response.status_code == 200:
            print("Image generated successfully!")

            # Display the generated image
            generated_image = Image.open(BytesIO(diffusion_response.content))
            generated_image.show()

        else:
            print(f"Error generating image with Diffusion model: {diffusion_response.status_code} - {diffusion_response.text}")
# Out:
# Enter the occasion for dressing up: indian festival
# Ask the model a question about the dress or type 'exit' to end the chat: suggest
# Select the type of suggestions you want:
# 1. Outfit
# 2. Accessories
# 3. Shoes
# 4. Handbags
# Enter the option number: 1,2,3
#  For the Indian festival occasion, you might want to consider outfits that are traditional, festive, and elegant. Here are some suggestions:
#
# Outfit:
# 1. Saree - A classic choice for women during Indian festivals. There are many types of sarees with intricate designs and patterns, which would be perfect for this occasion. You can choose from a variety of colors like reds, pinks, greens, oranges that are typically associated with Indian celebrations.
# 2. Salwar Kameez - This two-piece outfit is also commonly worn during festivals. Opt for bright colors and patterns, and you could pair it with a traditional dupatta.
# ...

# %%
# !pip install diffusers
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# ...

# %%
# !pip install --upgrade protobuf>=3.19.0
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# ...

# %%
# !pip install --upgrade protobuf<=3.20.0
# Out:
# The system cannot find the file specified.

# %%
# !pip install --upgrade diffusers[torch]
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# ...

# %%
import os

os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

# %%
pip install replicate
# Out:
# ...
#   Using cached pydantic-2.6.4-py3-none-any.whl (394 kB)
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\aksha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogleapis-common-protos (c:\users\aksha\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# # Suggestion + Image generation

# %%
import os
import base64
import requests
from PIL import Image
from io import BytesIO

# API endpoint URLs
llava_url = 'http://8.12.5.48:11434/api/generate'
runwayml_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
first_image_link = None  # Variable to store the link of the first image
modifications = []  # List to store user-specified modifications

while True:
    # Prompt the user for a question or exit option
    user_input = input("Ask the model a question about the dress or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to select the type of suggestions they want
    print("Select the type of suggestions you want:")
    print("1. Outfit")
    print("2. Accessories")
    print("3. Shoes")
    print("4. Handbags")
    option = input("Enter the option number: ")

    # Add selected options to the LLAVA prompt
    selected_options = []
    if '1' in option:
        selected_options.append('outfit')
    if '2' in option:
        selected_options.append('accessories')
    if '3' in option:
        selected_options.append('shoes')
    if '4' in option:
        selected_options.append('handbags')

    # Add a string before the user's question for LLAVA prompt
    llava_prompt = f'''For the given input, always describe the dress and whether the dress looks like men's or women's dress. 
    Importantly, never give suggestions for all genders together. Understand whether the outfit the outfit belongs to men or women or unisex and
    give suggestions for that gender alone. For example: if the dress looks feminine, suggesting a good chain or earrings is desirable. Compress your suggestions to 3 concise lines maximum and be very clear.
    Give as much visual representations as possible: {user_input}

    User selected options: {", ".join(selected_options)}'''

    if first_image_link is None:
        # Read and encode the first image in base64
        first_image_path = os.getcwd() + '\\dress_B0006HJ91S.jpg'
        with open(first_image_path, 'rb') as first_image_file:
            first_image_data = base64.b64encode(first_image_file.read()).decode('utf-8')
        first_image_link = first_image_data  # Store the link for the first image

    # Apply previous modifications to the LLAVA prompt
    modified_prompt = llava_prompt
    for mod in modifications:
        modified_prompt += f"\n{mod}"

    # Payload data for LLAVA model with image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": modified_prompt,
        "stream": False,
        "images": [first_image_link]  # Use the link of the first image as input
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Check if the user wants to change the dress and there is a suggestion from LLAVA
    if change_dress and llava_suggestion:
        # Payload data for Diffusion model
        diffusion_payload = {
            "inputs": llava_suggestion
        }
        
        # Send POST request to Diffusion model
        diffusion_response = requests.post(runwayml_url, json=diffusion_payload, headers=headers)

        if diffusion_response.status_code == 200:
            print("Image generated successfully!")

            # Display the generated image
            generated_image = Image.open(BytesIO(diffusion_response.content))
            generated_image.show()

        else:
            print(f"Error generating image with Diffusion model: {diffusion_response.status_code} - {diffusion_response.text}")
# Out:
# Ask the model a question about the dress or type 'exit' to end the chat: suggest
# Select the type of suggestions you want:
# 1. Outfit
# 2. Accessories
# 3. Shoes
# 4. Handbags
# Enter the option number: 1,2,3
#  The dress in the image is a women's dress, characterized by its deep V-neckline and the way it accentuates the wearer's silhouette. As an assistant, I would suggest:
#
# 1. A pair of statement earrings that complement the V-neckline of the dress.
# 2. High heels to elongate the legs and add a touch of elegance to the overall look.
# 3. A clutch purse in a neutral color to balance the boldness of the outfit without overpowering it.
# Do you want to change your dress according to LLAVA's suggestion? (yes/no): yes
# Image generated successfully!
# Ask the model a question about the dress or type 'exit' to end the chat: exit
# Exiting the chat.

# %%
import os
import base64
import requests
from PIL import Image
from io import BytesIO

# API endpoint URLs
llava_url = 'http://8.12.5.48:11434/api/generate'
runwayml_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
first_image_link = None  # Variable to store the link of the first image
modifications = []  # List to store user-specified modifications

while True:
    # Prompt the user for a question or exit option
    user_input = input("Press any key to get suggestions about your outfit or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to select the type of suggestions they want
    print("Select the type of suggestions you want:")
    print("1. Outfit")
    print("2. Accessories")
    print("3. Shoes")
    print("4. Handbags")
    option = input("Enter the option number: ")

    # Add selected options to the LLAVA prompt
    selected_options = []
    if '1' in option:
        selected_options.append('outfit')
    if '2' in option:
        selected_options.append('accessories')
    if '3' in option:
        selected_options.append('shoes')
    if '4' in option:
        selected_options.append('handbags')

    # Add a string before the user's question for LLAVA prompt
    llava_prompt = f'''For the given input, always describe the dress and whether the dress looks like men's or women's dress. 
    Importantly, never give suggestions for all genders together. Understand whether the outfit the outfit belongs to men or women or unisex and
    give suggestions for that gender alone. For example: if the dress looks feminine, suggesting a good chain or earrings is desirable. Compress your suggestions to 3 concise lines maximum and be very clear.
    Give as much visual representations as possible: {user_input}

    User selected options: {", ".join(selected_options)}'''

    if first_image_link is None:
        # Read and encode the first image in base64
        first_image_path = os.getcwd() + '\\dress_B0006HJ91S.jpg'
        with open(first_image_path, 'rb') as first_image_file:
            first_image_data = base64.b64encode(first_image_file.read()).decode('utf-8')
        first_image_link = first_image_data  # Store the link for the first image

    # Apply previous modifications to the LLAVA prompt
    modified_prompt = llava_prompt
    for mod in modifications:
        modified_prompt += f"\n{mod}"

    # Payload data for LLAVA model with image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": modified_prompt,
        "stream": False,
        "images": [first_image_link]  # Use the link of the first image as input
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Check if the user wants to change the dress and there is a suggestion from LLAVA
    if change_dress and llava_suggestion:
        # Payload data for Diffusion model
        diffusion_payload = {
            "inputs": llava_suggestion
        }
        
        # Send POST request to Diffusion model
        diffusion_response = requests.post(runwayml_url, json=diffusion_payload, headers=headers)

        if diffusion_response.status_code == 200:
            print("Image generated successfully!")

            # Display the generated image
            generated_image = Image.open(BytesIO(diffusion_response.content))
            generated_image.show()

        else:
            print(f"Error generating image with Diffusion model: {diffusion_response.status_code} - {diffusion_response.text}")
# Out:
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: f
# Select the type of suggestions you want:
# 1. Outfit
# 2. Accessories
# 3. Shoes
# 4. Handbags
# Enter the option number: 1,2,3,4
#  The dress in the image appears to be a women's dress. It has a slit on one side and is strapless, which are typically characteristics of women's dresses.
#
# For this dress:
# - A statement necklace could elevate the look.
# - High-heeled sandals would complement the dress well.
# - A small clutch handbag for casual occasions or a larger evening bag for more formal events could complete the outfit.
# Do you want to change your dress according to LLAVA's suggestion? (yes/no): yes
# Error generating image with Diffusion model: 503 - {"error":"Model Adrenex/fastgen is currently loading","estimated_time":109.62496185302734}
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: exit
# Exiting the chat.

# %%
import os
import base64
import requests
from PIL import Image
from io import BytesIO
import time  # Import time module

# API endpoint URLs
llava_url = 'http://8.12.5.48:11434/api/generate'
runwayml_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
first_image_link = None  # Variable to store the link of the first image
modifications = []  # List to store user-specified modifications

def check_model_availability():
    availability_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'
    try:
        response = requests.head(availability_url)
        if response.status_code == 200:
            return True
    except Exception as e:
        print(f"Error checking model availability: {e}")
    return False

while True:
    # Prompt the user for a question or exit option
    user_input = input("Press any key to get suggestions about your outfit or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to select the type of suggestions they want
    print("Select the type of suggestions you want:")
    print("1. Outfit")
    print("2. Accessories")
    print("3. Shoes")
    print("4. Handbags")
    option = input("Enter the option number: ")

    # Add selected options to the LLAVA prompt
    selected_options = []
    if '1' in option:
        selected_options.append('outfit')
    if '2' in option:
        selected_options.append('accessories')
    if '3' in option:
        selected_options.append('shoes')
    if '4' in option:
        selected_options.append('handbags')

    # Add a string before the user's question for LLAVA prompt
    llava_prompt = f'''For the given input, always describe the dress and whether the dress looks like men's or women's dress. 
    Importantly, never give suggestions for all genders together. Understand whether the outfit belongs to men or women or unisex and
    give suggestions for that gender alone. For example: if the dress looks feminine, suggesting a good chain or earrings is desirable. Compress your suggestions to 3 concise lines maximum and be very clear.
    Give as much visual representations as possible: {user_input}

    User selected options: {", ".join(selected_options)}'''

    if first_image_link is None:
        # Read and encode the first image in base64
        first_image_path = os.getcwd() + '\\dress_B0006HJ91S.jpg'
        with open(first_image_path, 'rb') as first_image_file:
            first_image_data = base64.b64encode(first_image_file.read()).decode('utf-8')
        first_image_link = first_image_data  # Store the link for the first image

    # Apply previous modifications to the LLAVA prompt
    modified_prompt = llava_prompt
    for mod in modifications:
        modified_prompt += f"\n{mod}"

    # Payload data for LLAVA model with image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": modified_prompt,
        "stream": False,
        "images": [first_image_link]  # Use the link of the first image as input
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

        if change_dress and llava_suggestion:
            # Check Diffusion model availability
            if check_model_availability():
                # Payload data for Diffusion model
                diffusion_payload = {
                    "inputs": llava_suggestion
                }

                # Send POST request to Diffusion model
                diffusion_response = requests.post(runwayml_url, json=diffusion_payload, headers=headers)

                if diffusion_response.status_code == 200:
                    print("Image generated successfully!")

                    # Display the generated image
                    generated_image = Image.open(BytesIO(diffusion_response.content))
                    generated_image.show()

                else:
                    print(f"Error generating image with Diffusion model: {diffusion_response.status_code} - {diffusion_response.text}")

            else:
                print("Diffusion model is not available. Showing LLAVA suggestions only.")

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Wait for a few seconds before next iteration to avoid frequent requests
    time.sleep(5)
# Out:
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: f
# Select the type of suggestions you want:
# 1. Outfit
# 2. Accessories
# 3. Shoes
# 4. Handbags
# Enter the option number: 1,2,3
#  In the image, the woman is wearing a black sleeveless dress that features a deep V-neckline and reaches down to her knees. The dress appears to have a slit on one side, revealing one leg. This outfit is very feminine and would be most suitable for women's fashion.
#
# As for accessories, the woman has on a necklace which adds a touch of elegance to her look. For shoes, she has chosen a pair that seem to be strappy heels, providing an elegant finish to the ensemble. These shoes are also feminine in style and would complement the dress well.
# Do you want to change your dress according to LLAVA's suggestion? (yes/no): yes
# Diffusion model is not available. Showing LLAVA suggestions only.
# ...

# %% [markdown]
# # Find Similar dress

# %%
import base64
import requests
import csv
import os

# API endpoint URL for LLAVA
llava_url = 'http://8.12.5.48:11434/api/generate'

# Your Hugging Face token for authentication
hugging_face_token = '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'
base_url = os.getcwd()

# Load IDs and image links from a text file with different encodings
def load_image_data(file_path):
    encodings = ['utf-8', 'latin-1']  # Try different encodings
    data = []
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                for line in file:
                    parts = line.strip().split('\t')
                    if len(parts) == 2:
                        image_id, image_link = parts
                        image_link = image_link.strip()
                        data.append({'id': image_id, 'link': image_link})
            break  # Stop trying encodings if successful
        except UnicodeDecodeError:
            continue  # Try next encoding if decoding fails
    return data

# Generate LLAVA description for an image from URL or local file path
def generate_llava_description(image_source):
    try:
        if image_source.startswith('http://') or image_source.startswith('https://'):
            # Fetch the image from URL
            response = requests.get(image_source)
            response.raise_for_status()  # Raise an error if response status is not 200
            # Encode the image in base64
            image_data = base64.b64encode(response.content).decode('utf-8')
        else:
            # Read and encode the local image in base64
            with open(image_source, 'rb') as image_file:
                image_data = base64.b64encode(image_file.read()).decode('utf-8')

        # Payload data for LLAVA model with image input
        llava_payload = {
            "model": "llava:7b-v1.6-mistral-q5_K_M",
            "prompt": f"Generate a description for this image: {image_source}",
            "stream": False,
            "images": [image_data]
        }

        # Headers with Hugging Face token for authentication
        headers = {
            'Authorization': f'Bearer {hugging_face_token}'
        }

        # Send POST request to LLAVA model with authentication headers
        llava_response = requests.post(llava_url, json=llava_payload, headers=headers)
        llava_response.raise_for_status()  # Raise an error if response status is not 200

        llava_response_data = llava_response.json()
        description = llava_response_data['response']
        return description

    except requests.exceptions.RequestException as e:
        print(f"Error processing image: {e}")
        return None

# Load image data from the text file
image_data_file = base_url + '\\image_url\\images_txt.txt'  # Update with your file path
image_data = load_image_data(image_data_file)
#print("Image data: \n", image_data)

# Load existing descriptions from CSV if available
existing_descriptions = {}
csv_file = base_url + '\\image_descriptions.csv'
if os.path.isfile(csv_file):
    with open(csv_file, 'r', newline='', encoding='latin1') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if 'id' in row and 'link' in row and 'description' in row:
                existing_descriptions[row['id']] = {'link': row['link'], 'description': row['description']}

# Generate LLAVA descriptions for images and store/update them in CSV
with open(csv_file, 'a', newline='', encoding='latin1') as csvfile:
    fieldnames = ['id', 'link', 'description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    for item in image_data:
        image_id = item['id']
        image_link = item['link']
        if image_id not in existing_descriptions:
            print(f"Generating LLAVA description for image with ID: {image_id}")
            description = generate_llava_description(image_link)
            if description:
                existing_descriptions[image_id] = {'link': image_link, 'description': description}
                writer.writerow({'id': image_id, 'link': image_link, 'description': description})
                print(f"LLAVA description saved for image with ID: {image_id}")

# User input image (local file path or URL)
user_image_source = base_url + '\\dress_B0006HJ91S.jpg'  # Update with your image path or URL
user_image_description = generate_llava_description(user_image_source)

if user_image_description:
    print(f"LLAVA description for user input image: {user_image_description}")
else:
    print("Failed to generate LLAVA description for user input image.")
# Out:
# Generating LLAVA description for image with ID: B00014NGF6
# LLAVA description saved for image with ID: B00014NGF6
# Generating LLAVA description for image with ID: B0006HJ8FU
# LLAVA description saved for image with ID: B0006HJ8FU
# Generating LLAVA description for image with ID: B0006HJ91S
# LLAVA description saved for image with ID: B0006HJ91S
# Generating LLAVA description for image with ID: B0006HJBCA
# LLAVA description saved for image with ID: B0006HJBCA
# Generating LLAVA description for image with ID: B0006HJBGG
# LLAVA description saved for image with ID: B0006HJBGG
# Generating LLAVA description for image with ID: B0006I3E7W
# LLAVA description saved for image with ID: B0006I3E7W
# Generating LLAVA description for image with ID: B0006VN9EW
# LLAVA description saved for image with ID: B0006VN9EW
# Generating LLAVA description for image with ID: B0007V0ZYS
# LLAVA description saved for image with ID: B0007V0ZYS
# Generating LLAVA description for image with ID: B0007V2YEM
# ...

# %%
import base64
import requests
import csv
import os

# API endpoint URL for LLAVA
llava_url = 'http://8.12.5.48:11434/api/generate'

# Your Hugging Face token for authentication
hugging_face_token = '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'
base_url = os.getcwd()

# Load IDs and image links from a text file with different encodings
def load_image_data(file_path):
    encodings = ['iso-8859-1', 'utf-8', 'latin-1']  # Try different encodings
    data = []
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                for line in file:
                    parts = line.strip().split('\t')
                    if len(parts) == 2:
                        image_id, image_link = parts
                        image_link = image_link.strip()
                        data.append({'id': image_id, 'link': image_link})
            break  # Stop trying encodings if successful
        except UnicodeDecodeError:
            continue  # Try next encoding if decoding fails
    return data

# Generate LLAVA description for an image from URL or local file path
def generate_llava_description(image_source):
    encodings = ['iso-8859-1', 'utf-8', 'latin-1'] 
    try:
        if image_source.startswith('http://') or image_source.startswith('https://'):
            # Fetch the image from URL
            response = requests.get(image_source)
            response.raise_for_status()  # Raise an error if response status is not 200
            # Encode the image in base64
            image_data = base64.b64encode(response.content).decode('utf-8')
        else:
            # Read and encode the local image in base64
            with open(image_source, 'rb') as image_file:
                image_data = base64.b64encode(image_file.read()).decode('utf-8')

        # Payload data for LLAVA model with image input
        llava_payload = {
            "model": "llava:7b-v1.6-mistral-q5_K_M",
            "prompt": f"Generate a description for this image: {image_source}",
            "stream": False,
            "images": [image_data]
        }

        # Headers with Hugging Face token for authentication
        headers = {
            'Authorization': f'Bearer {hugging_face_token}'
        }

        # Send POST request to LLAVA model with authentication headers
        llava_response = requests.post(llava_url, json=llava_payload, headers=headers)
        llava_response.raise_for_status()  # Raise an error if response status is not 200

        llava_response_data = llava_response.json()
        description = llava_response_data['response']
        return description

    except requests.exceptions.RequestException as e:
        print(f"Error processing image: {e}")
        return None

# Load image data from the text file
image_data_file = base_url + '\\image_url\\images_txt.txt'  # Update with your file path
image_data = load_image_data(image_data_file)
#print("Image data: \n", image_data)

# Load existing descriptions from CSV if available
existing_descriptions = {}
csv_file = base_url + '\\final_image_descriptions.csv'
if os.path.isfile(csv_file):
    for encoding in encodings:
        try:
            with open(csv_file, 'r', newline='', encoding=encoding) as csvfile:
                reader = csv.DictReader(csvfile)
                for row in reader:
                    if 'id' in row and 'link' in row and 'description' in row:
                        existing_descriptions[row['id']] = {'link': row['link'], 'description': row['description']}
            break  # Stop trying encodings if successful
        except UnicodeDecodeError:
            continue  # Try next encoding if decoding fails
'''
# Generate LLAVA descriptions for images and store/update them in CSV
with open(csv_file, 'a', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'link', 'description']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    for item in image_data:
        image_id = item['id']
        image_link = item['link']
        if image_id not in existing_descriptions:
            print(f"Generating LLAVA description for image with ID: {image_id}")
            description = generate_llava_description(image_link)
            if description:
                existing_descriptions[image_id] = {'link': image_link, 'description': description}
                writer.writerow({'id': image_id, 'link': image_link, 'description': description})
                print(f"LLAVA description saved for image with ID: {image_id}")
        else:
            print(f"Description for image with ID {image_id} already exists in CSV.")
'''
# User input image (local file path or URL)
user_image_source = base_url + '\\dress_B0006HJ91S.jpg'  # Update with your image path or URL
user_image_description = generate_llava_description(user_image_source)

if user_image_description:
    print(f"LLAVA description for user input image: {user_image_description}")
else:
    print("Failed to generate LLAVA description for user input image.")
# Out:
# LLAVA description for user input image:  The image shows a woman posing for the photo. She is wearing a black, sleeveless dress with a thigh-high slit on one side, revealing her muscular leg and calf. Her body posture is confident and assertive, with her hands placed on her hips. She has dark hair and a visible tattoo on her left arm. The woman's gaze is directed straight ahead, and she has a neutral expression on her face. The background of the image is plain white, which contrasts with her attire and highlights her. There are no visible texts or branding in the image. The style of the photo appears to be a promotional or fashion-related photograph, possibly for an athleisure or fitness clothing line.

# %%
existing_descriptions
# Out:
# {}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Preprocess the description text
def preprocess_text(text):
    # Remove non-alphanumeric characters
    text = ''.join(e for e in text if e.isalnum() or e.isspace())
    # Convert to lowercase and tokenize
    tokens = text.lower().split()
    return ' '.join(tokens)

# Function to calculate cosine similarity between two vectors
def calculate_similarity(description1, description2):
    # Use TF-IDF vectorization for numerical representation
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([description1, description2])
    # Calculate cosine similarity
    similarity = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
    return similarity

# User image description (replace with actual description)
#user_description = "Your user image description here"

most_similar_image = None
highest_similarity = 0.0

# Iterate through existing descriptions and find the most similar image
for image_id, data in existing_descriptions.items():
    existing_description = preprocess_text(data['description'])
    user_description_preprocessed = preprocess_text(user_image_description)
    similarity = calculate_similarity(existing_description, user_description_preprocessed)
    if similarity > highest_similarity:
        highest_similarity = similarity
        most_similar_image = {'id': image_id, 'link': data['link'], 'description': existing_description}

# Print the most similar image information
if most_similar_image:
    print(f"The most similar image is ID: {most_similar_image['id']}, Link: {most_similar_image['link']}")
    print(f"Similarity score: {highest_similarity}")
else:
    print("No similar image found.")
# Out:
# No similar image found.

# %%
import pandas as pd
df = pd.read_csv(base_url+"\\image_descriptions.csv", encoding = 'latin1', header=None)
new_columns=['ID', 'Link', 'Description']
df.columns=new_columns
print(df.shape)
# Out:
# (438, 3)

# %%
df.head(3)
# Out:
#             ID                                               Link  \
# 0  B00014NGF6   http://ecx.images-amazon.com/images/I/51AERD8S...
# 1  B0006HJ8FU   http://ecx.images-amazon.com/images/I/31kdO0Sg...
# 2  B0006HJ91S   http://ecx.images-amazon.com/images/I/31c9O%2B...
#
#                                          Description
# 0   In the image, a woman with short hair is seat...
# 1   The image shows a woman in a long, black even...
# 2   The image features a woman standing against a...

# %%
df= df.drop_duplicates(subset=['ID'], keep='first')
print(df.shape)
# Out:
# (149, 3)

# %%
df.to_csv('final_image_descriptions.csv', index=None)

# %%
df = pd.read_csv(base_url+"\\final_image_descriptions.csv", encoding = 'latin1')
df.head(5)
# Out:
#             ID                                               Link  \
# 0  B00014NGF6   http://ecx.images-amazon.com/images/I/51AERD8S...
# 1  B0006HJ8FU   http://ecx.images-amazon.com/images/I/31kdO0Sg...
# 2  B0006HJ91S   http://ecx.images-amazon.com/images/I/31c9O%2B...
# 3  B0006HJBCA   http://ecx.images-amazon.com/images/I/310t8UNM...
# 4  B0006HJBGG   http://ecx.images-amazon.com/images/I/31u6rJMI...
#
#                                          Description
# 0   In the image, a woman with short hair is seat...
# 1   The image shows a woman in a long, black even...
# 2   The image features a woman standing against a...
# 3   The image features a woman standing against a...
# 4   The image shows a woman standing in front of ...

# %%
import base64
import requests
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import Image, display, HTML

# Your existing code

# Load existing descriptions from CSV
csv_file = base_url + '\\final_image_descriptions.csv'
existing_descriptions_df = pd.read_csv(csv_file, encoding='utf-8')

# Preprocess descriptions for similarity calculation
existing_descriptions_df['Preprocessed_description'] = existing_descriptions_df['Description'].apply(preprocess_text)

# User input image (local file path or URL)
user_image_source = base_url + '\\dress_B0006HJ91S.jpg'  # Update with your image path or URL
user_image_description = generate_llava_description(user_image_source)

if user_image_description:
    print(f"LLAVA description for user input image: {user_image_description}")
    user_description_preprocessed = preprocess_text(user_image_description)
else:
    print("Failed to generate LLAVA description for user input image.")

most_similar_image = None
highest_similarity = 0.0
vectorizer = TfidfVectorizer()
# Iterate through existing descriptions and find the most similar image
for index, row in existing_descriptions_df.iterrows():
    existing_description = row['Preprocessed_description']
    similarity = cosine_similarity(
        vectorizer.fit_transform([existing_description, user_description_preprocessed])
    )[0][1]
    if similarity > highest_similarity:
        highest_similarity = similarity
        most_similar_image = {'ID': row['ID'], 'Link': row['Link'], 'Description': existing_description}

# Print the most similar image information and display the image
if most_similar_image:
    print(f"The most similar image is ID: {most_similar_image['ID']}, Link: {most_similar_image['Link']}")
    print(f"Similarity score: {highest_similarity}")
    
    # Display the most similar image and link
    image_url = most_similar_image['Link']
    display(HTML(f'<img src="{image_url}" style="max-width:400px;"><br><a href="{image_url}" target="_blank">Link to Image</a>'))
else:
    print("No similar image found.")
# Out:
# LLAVA description for user input image:  The image shows a woman posing in a black sleeveless dress with a deep neckline, revealing her midriff. She is standing with one hand on her hip and the other hanging by her side, displaying a confident stance. Her left arm is extended downward, showcasing her well-defined bicep. The woman has long dark hair, and she appears to be in her late 20s to early 30s. She is wearing high heels that are not fully visible due to the angle of the photo.
#
# The background is plain and light-colored, providing a clear contrast with her dark dress. There are no visible texts or logos in the image, and it appears to be a staged photograph possibly for promotional purposes or modeling. The focus is solely on the woman and her attire, suggesting that she might be a fitness model or athlete given the context of the attire.
# The most similar image is ID: B0006HJBCA , Link: http://ecx.images-amazon.com/images/I/310t8UNMt4L._SY445_.jpg
# ...

# %% [markdown]
# # Based on Country

# %%
import base64
import requests
from PIL import Image
from io import BytesIO
import time  # Import time module

# API endpoint URL for LLAVA
llava_url = 'http://8.12.5.48:11434/api/generate'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
modifications = []  # List to store user-specified modifications

def check_model_availability():
    availability_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'
    try:
        response = requests.head(availability_url)
        if response.status_code == 200:
            return True
    except Exception as e:
        print(f"Error checking model availability: {e}")
    return False

def generate_image(hugging_face_token, inputs):
    # API endpoint URL for Hugging Face image generation model
    hugging_face_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Payload data for Hugging Face image generation model
    payload = {
        'inputs': inputs
    }

    # Send POST request to Hugging Face image generation model
    response = requests.post(hugging_face_url, json=payload, headers=headers)

    if response.status_code == 200:
        return response.content
    else:
        print(f"Error generating image with Hugging Face model: {response.status_code} - {response.text}")
        return None

while True:
    # Prompt the user for a question or exit option
    user_input = input("Press any key to get suggestions about your outfit or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to enter the country's name and their gender
    country_name = input("Enter the name of the country you want to dress like: ")
    gender = input("Enter your gender (male/female/non-binary): ")

    # Add country and gender information to the LLAVA prompt
    llava_prompt = f'''For the given counrty and gender: {country_name}, {gender} generate appropriate dress and
    accessories.

    User selected options: outfit'''

    # Payload data for LLAVA model without image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": llava_prompt,
        "stream": False
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

        if change_dress and llava_suggestion:
            # Generate image using Hugging Face model
            generated_image_data = generate_image(hugging_face_token, llava_suggestion)
            if generated_image_data:
                print("Image generated successfully!")
                # Display the generated image
                generated_image = Image.open(BytesIO(generated_image_data))
                generated_image.show()

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Wait for a few seconds before next iteration to avoid frequent requests
    time.sleep(5)
# Out:
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: f
# Enter the name of the country you want to dress like: india
# Enter your gender (male/female/non-binary): male
#  For a male in India, one suitable outfit could be traditional Indian attire such as kurta pajama or churidar with a sherwani. Accessories to complement this look could include a turban, jutti footwear, and perhaps a watch or a piece of jewelry like a bracelet or a wristband.
# Do you want to change your dress according to LLAVA's suggestion? (yes/no): yes
# Image generated successfully!
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: exit
# Exiting the chat.

# %%
import base64
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt  # Import Matplotlib for plotting
import time  # Import time module

# API endpoint URL for LLAVA
llava_url = 'http://8.12.5.48:11434/api/generate'

# Your Hugging Face token for authentication
hugging_face_token = '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'

# Initialize variables
llava_suggestion = ''
change_dress = False
modifications = []  # List to store user-specified modifications

def check_model_availability():
    availability_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'
    try:
        response = requests.head(availability_url)
        if response.status_code == 200:
            return True
    except Exception as e:
        print(f"Error checking model availability: {e}")
    return False

def generate_image(hugging_face_token, inputs):
    # API endpoint URL for Hugging Face image generation model
    hugging_face_url = 'https://api-inference.huggingface.co/models/Adrenex/fastgen'

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Payload data for Hugging Face image generation model
    payload = {
        'inputs': inputs
    }

    # Send POST request to Hugging Face image generation model
    response = requests.post(hugging_face_url, json=payload, headers=headers)

    if response.status_code == 200:
        return response.content
    else:
        print(f"Error generating image with Hugging Face model: {response.status_code} - {response.text}")
        return None

while True:
    # Prompt the user for a question or exit option
    user_input = input("Press any key to get suggestions about your outfit or type 'exit' to end the chat: ")

    # Check if the user wants to exit
    if user_input.lower() == 'exit':
        print("Exiting the chat.")
        break

    # Prompt the user to enter the country's name and their gender
    country_name = input("Enter the name of the country you want to dress like: ")
    gender = input("Enter your gender (male/female/non-binary): ")

    # Add country and gender information to the LLAVA prompt
    llava_prompt = f'''For the given counrty and gender: {country_name}, {gender} generate appropriate dress and
    accessories.

    User selected options: outfit'''

    # Payload data for LLAVA model without image input
    llava_payload = {
        "model": "llava:7b-v1.6-mistral-q5_K_M",
        "prompt": llava_prompt,
        "stream": False
    }

    # Headers with Hugging Face token for authentication
    headers = {
        'Authorization': f'Bearer {hugging_face_token}'
    }

    # Send POST request to LLAVA model with authentication headers
    llava_response = requests.post(llava_url, json=llava_payload, headers=headers)

    # Check response status from LLAVA model
    if llava_response.status_code == 200:
        # Get the LLAVA model's response
        llava_response_data = llava_response.json()
        llava_suggestion = llava_response_data['response']
        print(llava_response_data['response'])
        # Check if the user wants to change the dress based on LLAVA suggestion
        change_dress_input = input("Do you want to change your dress according to LLAVA's suggestion? (yes/no): ")

        if change_dress_input.lower() == 'yes':
            change_dress = True

        if change_dress and llava_suggestion:
            # Generate image using Hugging Face model
            generated_image_data = generate_image(hugging_face_token, llava_suggestion)
            if generated_image_data:
                print("Image generated successfully!")
                # Display the generated image using Matplotlib
                img = Image.open(BytesIO(generated_image_data))
                plt.imshow(img)
                plt.axis('off')  # Turn off axis for cleaner display
                plt.show()

    else:
        print(f"Error accessing the LLAVA model: {llava_response.status_code} - {llava_response.text}")

    # Wait for a few seconds before next iteration to avoid frequent requests
    time.sleep(5)
# Out:
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: f
# Enter the name of the country you want to dress like: India
# Enter your gender (male/female/non-binary): male
#  Sure, here are some appropriate outfits and accessories for a male in India:
#
# Outfit: A traditional Indian outfit such as a kurta or a mundu paired with chappals would be perfect. Alternatively, you can opt for a casual t-shirt and jeans.
#
# Accessories: To complete the look, some appropriate accessories would include a watch, a pair of sunglasses, and a belt to complement the outfit. Additionally, a traditional Indian hat or cap could add a touch of authenticity to the overall look.
# Do you want to change your dress according to LLAVA's suggestion? (yes/no): yes
# Image generated successfully!
# Press any key to get suggestions about your outfit or type 'exit' to end the chat: exit
# Exiting the chat.
